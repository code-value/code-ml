# %%
import pandas as pd

import numpy

import tensorflow

# %%
db=pd.read_csv("pima-indians-diabetes.data.csv",header=None)

# %%
db.head(5)
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
y=db[8]

# %%
x=db.iloc[:,0:8]

# %%
x
# Out:
#       0    1   2   3    4     5      6   7
# 0     6  148  72  35    0  33.6  0.627  50
# 1     1   85  66  29    0  26.6  0.351  31
# 2     8  183  64   0    0  23.3  0.672  32
# 3     1   89  66  23   94  28.1  0.167  21
# 4     0  137  40  35  168  43.1  2.288  33
# ..   ..  ...  ..  ..  ...   ...    ...  ..
# 763  10  101  76  48  180  32.9  0.171  63
# 764   2  122  70  27    0  36.8  0.340  27
# 765   5  121  72  23  112  26.2  0.245  30
# 766   1  126  60   0    0  30.1  0.349  47
# 767   1   93  70  31    0  30.4  0.315  23
#
# [768 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test = tts(x,y,test_size=0.20)

# %%
from keras.models import Sequential

# %%
model=Sequential()

# %%
from keras.layers import Dense

# %%
model.add(Dense(units=4,kernel_initializer="Zeros",bias_initializer="Zeros", activation="relu",input_dim=8))

# %%
model.add(Dense(units=4,kernel_initializer="Zeros",bias_initializer="Zeros", activation="relu"))

# %%
model.add(Dense(units=1,kernel_initializer="Zeros",bias_initializer="Zeros", activation="sigmoid"))

# %%
from keras.optimizers import Adam 
model.compile(optimizer=Adam(learning_rate=0.00001),loss="binary_crossentropy", metrics="accuracy" )

# %%
history=model.fit(x_train,y_train, epochs=100)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 29s 7ms/step - loss: 0.6931 - accuracy: 0.6744
# Epoch 2/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.6506
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.6744
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.6379
# Epoch 5/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.6518
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.6524
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.6413
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.6671
# Epoch 9/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.65 - 0s 2ms/step - loss: 0.6929 - accuracy: 0.6661
# Epoch 10/100
# ...

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['loss'])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-56f48285b83f> in <module>
# ----> 1 model.evalu
#
# AttributeError: 'Sequential' object has no attribute 'evalu'
